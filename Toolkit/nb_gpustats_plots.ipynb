# %%
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 400)
pd.set_option('display.max_rows', None)

from utils_gpustats import process_gpu_log, plot_gpu_utilization

# Process GPU Utilization Data

# Set file directory
model_name = 'ObjectDetection'
log_folder = 'P100_20230809231345' # 'A30_20230809212333_batch16' # 'A30_20230810051900_batch64' # 'A30_20230810081433_batch96'

log_path = os.path.join('../', model_name, 'memprof', log_folder)

# Find file name in the folder that starts with 'gpustat'
for file in os.listdir(os.path.join('../', model_name, 'memprof', log_folder)):
    if file.startswith('gpustat'):
        gpustat_file_name = file

log_file = os.path.join(log_path, gpustat_file_name)

#log_file = '/home/gojian/Projects/GPU_benchmarking_toolkit_for_ML/ImageClassification/memprof/A30_20230810131125/gpustat_A30PCIe-b526_20230810131125.log'

gpu_dfs = process_gpu_log(open(log_file, 'r'), logging_frequency_s = 2, gpu_nums = 2)

plot_gpu_utilization(gpu_dfs, model_name, log_folder, log_path)

# %%
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 400)
pd.set_option('display.max_rows', None)

from utils_gpustats import process_gpu_log, plot_gpu_utilization

# Process GPU Utilization Data

# Set file directory
model_name = 'ImageSegmentation'
log_folder = 'V100_20230808160853' # 'P100_20230808151917' # 'A30_20230808143714'

log_path = os.path.join('../', model_name, 'memprof', log_folder)

# Find file name in the folder that starts with 'gpustat'
for file in os.listdir(os.path.join('../', model_name, 'memprof', log_folder)):
    if file.startswith('gpustat'):
        gpustat_file_name = file

log_file = os.path.join(log_path, gpustat_file_name)

#log_file = '/home/gojian/Projects/GPU_benchmarking_toolkit_for_ML/ImageClassification/memprof/A30_20230810131125/gpustat_A30PCIe-b526_20230810131125.log'

gpu_dfs = process_gpu_log(open(log_file, 'r'), logging_frequency_s = 2, gpu_nums = 2)

plot_gpu_utilization(gpu_dfs, model_name, log_folder, log_path)

# %%
import os
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 400)
pd.set_option('display.max_rows', None)

# Process GPU Utilization Data

# Set file directory
model_name = 'ImageClassification'
log_folder = 'P100_20230810115557' # 'A30_20230810131125'

log_path = os.path.join('../', model_name, 'memprof', log_folder)

# Find file name in the folder that starts with 'gpustat'
for file in os.listdir(os.path.join('../', model_name, 'memprof', log_folder)):
    if file.startswith('gpustat'):
        gpustat_file_name = file

log_file = os.path.join(log_path, gpustat_file_name)

#log_file = '/home/gojian/Projects/GPU_benchmarking_toolkit_for_ML/ImageClassification/memprof/A30_20230810131125/gpustat_A30PCIe-b526_20230810131125.log'

gpu_dfs = process_gpu_log(open(log_file, 'r'), logging_frequency_s = 2, gpu_nums = 2)

plot_gpu_utilization(gpu_dfs, model_name, log_folder, log_path)
